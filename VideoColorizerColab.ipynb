# %% [markdown]
# <a href="https://colab.research.google.com/github/WILIANTAR/tal-fagote-potencial/blob/main/VideoColorizerColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **<font color='blue'> Video Colorizer </font>**

# %% [markdown]
# #◢ DeOldify - Colorize your own videos!
#
#
# _FYI: This notebook is intended as a tool to colorize gifs and short videos, if you are trying to convert longer video you may hit the limit on processing space. Running the Jupyter notebook on your own machine is recommended (and faster) for larger video sizes._
#
# ####**Credits:**
#
# Big special thanks to:
#
# Robert Bell for all his work on the video Colab notebook, and paving the way to video in DeOldify!
#
# Dana Kelley for doing things, breaking stuff & having an opinion on everything.

# %% [markdown]
# ---
#
#
# #◢ Verify Correct Runtime Settings
#
# **<font color='#FF000'> IMPORTANT </font>**
#
# In the "Runtime" menu for the notebook window, select "Change runtime type." Ensure that the following are selected:
# * Runtime Type = Python 3
# * Hardware Accelerator = GPU

# %% [markdown]
# #◢ Git clone and install DeOldify

# %%
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# Out:
# fatal: destination path 'DeOldify' already exists and is not an empty directory.

# %%
cd DeOldify
# Out:
# /content/DeOldify

# %% [markdown]
# #◢ Setup

# %%
#NOTE:  This must be the first call in order to work properly!
from deoldify import device
from deoldify.device_id import DeviceId
#choices:  CPU, GPU0...GPU7
device.set(device=DeviceId.GPU0)

import torch

if not torch.cuda.is_available():
    print('GPU not available.')

from os import path

# %%
# !pip install -r requirements-colab.txt
# Out:
# Requirement already satisfied: fastai==1.0.60 in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 1)) (1.0.60)
# Requirement already satisfied: tensorboardX>=1.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 2)) (2.6.4)
# Requirement already satisfied: ffmpeg-python in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 3)) (0.2.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 4)) (2026.3.17)
# Requirement already satisfied: opencv-python>=4.2.0.32 in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 5)) (4.13.0.92)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 6)) (11.3.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 7)) (6.5.1)
# Requirement already satisfied: imgaug==0.2.6 in /usr/local/lib/python3.12/dist-packages (from -r requirements-colab.txt (line 8)) (0.2.6)
# Requirement already satisfied: bottleneck in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.4.2)
# Requirement already satisfied: fastprogress>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.1.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.13.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.10.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.14.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.0.2)
# Requirement already satisfied: nvidia-ml-py3 in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (7.352.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (26.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.32.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.16.3)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.10.0+cu128)
# Requirement already satisfied: spacy>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.8.11)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.25.0+cu128)
# Requirement already satisfied: scikit-image>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from imgaug==0.2.6->-r requirements-colab.txt (line 8)) (0.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from imgaug==0.2.6->-r requirements-colab.txt (line 8)) (1.17.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardX>=1.6->-r requirements-colab.txt (line 2)) (5.29.6)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python->-r requirements-colab.txt (line 3)) (1.0.0)
# Requirement already satisfied: fastcore>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.12.26)
# Requirement already satisfied: python-fasthtml>=0.12.34 in /usr/local/lib/python3.12/dist-packages (from fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.12.50)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.11.0->imgaug==0.2.6->-r requirements-colab.txt (line 8)) (0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.67.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.12.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (75.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2026.2.25)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.14.0)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.4.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.4.2)
# Requirement already satisfied: starlette>0.33 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.52.1)
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.12/dist-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.3.1)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.12/dist-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.2.0)
# Requirement already satisfied: uvicorn>=0.30 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.42.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.28.1)
# Requirement already satisfied: fastlite>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.2.4)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.0.22)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.1.5)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.24.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (7.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.0.3)
# Requirement already satisfied: apswutils>=0.1.2 in /usr/local/lib/python3.12/dist-packages (from fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.1.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.1.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette>0.33->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.12.1)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.0.4)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.30->uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.16.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.2.2)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.30->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (15.0.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (1.0.9)
# Requirement already satisfied: apsw in /usr/local/lib/python3.12/dist-packages (from apswutils>=0.1.2->fastlite>=0.1.1->python-fasthtml>=0.12.34->fastprogress>=0.2.1->fastai==1.0.60->-r requirements-colab.txt (line 1)) (3.51.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim<1.0.0,>=0.3.0->spacy>=2.0.18->fastai==1.0.60->-r requirements-colab.txt (line 1)) (0.1.2)

# %%
import fastai
from deoldify.visualize import *
from pathlib import Path
torch.backends.cudnn.benchmark=True
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*?Your .*? set is empty.*?")
# Out:
# /content/DeOldify/deoldify/visualize.py:223: SyntaxWarning: invalid escape sequence '\.'
#   if re.search('.*?\.jpg', f):
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# NumExpr defaulting to 2 threads.
# /content/DeOldify/fastai/gen_doc/gen_notebooks.py:63: SyntaxWarning: invalid escape sequence '\s'
#   match = re.match(f"^({key})\s*=\s*.*", codestr)
# /content/DeOldify/fastai/gen_doc/gen_notebooks.py:216: SyntaxWarning: invalid escape sequence '\('
#   if re.search(f"update_nb_metadata\('{fn}'", c['source']): return c
# /content/DeOldify/fastai/gen_doc/nbdoc.py:26: SyntaxWarning: invalid escape sequence '\*'
#   arg_prefixes = {inspect._VAR_POSITIONAL: '\*', inspect._VAR_KEYWORD:'\*\*'}
# /content/DeOldify/fastai/gen_doc/nbdoc.py:26: SyntaxWarning: invalid escape sequence '\*'
#   arg_prefixes = {inspect._VAR_POSITIONAL: '\*', inspect._VAR_KEYWORD:'\*\*'}
# /content/DeOldify/fastai/gen_doc/nbdoc.py:56: SyntaxWarning: invalid escape sequence '\['
#   return f'`Optional`\[{type_repr(args[0])}\]'
# /content/DeOldify/fastai/gen_doc/nbdoc.py:56: SyntaxWarning: invalid escape sequence '\]'
#   return f'`Optional`\[{type_repr(args[0])}\]'
# /content/DeOldify/fastai/gen_doc/nbdoc.py:58: SyntaxWarning: invalid escape sequence '\['
#   return f'{link_type(t)}\[{reprs}\]'
# /content/DeOldify/fastai/gen_doc/nbdoc.py:58: SyntaxWarning: invalid escape sequence '\]'
#   return f'{link_type(t)}\[{reprs}\]'
# /content/DeOldify/fastai/gen_doc/nbdoc.py:172: SyntaxWarning: invalid escape sequence '\['
#   BT_REGEX = re.compile("\[`([^`]*)`\](?:\([^)]*\))|`([^`]*)`") # matches [`key`](link) or `key`
# /content/DeOldify/fastai/gen_doc/docstrings.py:26: SyntaxWarning: invalid escape sequence '\*'
#   NEW_REGEX = re.compile(f":(?P<field>{FIELDS}) (?P<name>[\*\w]+): (?P<doc>.*?)"
# /content/DeOldify/fastai/gen_doc/docstrings.py:27: SyntaxWarning: invalid escape sequence '\Z'
#   f"(?:(?=:(?:{FIELDS}|return|raises))|\Z)", re.S)
# /content/DeOldify/fastai/gen_doc/nbtest.py:111: SyntaxWarning: invalid escape sequence '\w'
#   exact_re = '' if exact_match else '\w*'
# /content/DeOldify/fastai/gen_doc/nbtest.py:112: SyntaxWarning: invalid escape sequence '\w'
#   return re.match(f'test_{subdir}\w*{Path(fp).stem}{exact_re}\.py', file_name)
# /content/DeOldify/fastai/gen_doc/nbtest.py:112: SyntaxWarning: invalid escape sequence '\.'
#   return re.match(f'test_{subdir}\w*{Path(fp).stem}{exact_re}\.py', file_name)
# /content/DeOldify/fastai/gen_doc/nbtest.py:155: SyntaxWarning: invalid escape sequence '\s'
#   if re.match(f'.*[\s\.\(]{fn_name}[\.\(]', line):
# /content/DeOldify/fastai/gen_doc/nbtest.py:155: SyntaxWarning: invalid escape sequence '\.'
#   if re.match(f'.*[\s\.\(]{fn_name}[\.\(]', line):
# /content/DeOldify/fastai/gen_doc/nbtest.py:164: SyntaxWarning: invalid escape sequence '\s'
#   test_name = re.match(f'\s*def (test_\w*)', line_text).groups(0)[0]
# /content/DeOldify/fastai/gen_doc/doctest.py:121: SyntaxWarning: invalid escape sequence '\s'
#   if re.match(f'\s*def test', l):  return (lineno - idx), l # 1 based index for github
# /content/DeOldify/fastai/gen_doc/doctest.py:122: SyntaxWarning: invalid escape sequence '\w'
#   if re.match(f'\w+', l):  break # top level indent - out of function scope

# %%
# !mkdir 'models'
# !wget https://data.deepai.org/deoldify/ColorizeVideo_gen.pth -O ./models/ColorizeVideo_gen.pth
# Out:
# mkdir: cannot create directory ‘models’: File exists
# --2026-03-31 08:27:42--  https://data.deepai.org/deoldify/ColorizeVideo_gen.pth
# Resolving data.deepai.org (data.deepai.org)... 143.244.49.178, 2400:52e0:1a01::1000:1
# Connecting to data.deepai.org (data.deepai.org)|143.244.49.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 874066230 (834M) [application/octet-stream]
# Saving to: ‘./models/ColorizeVideo_gen.pth’
#
# ./models/ColorizeVi 100%[===================>] 833.57M  4.90MB/s    in 2m 50s
#
# 2026-03-31 08:30:32 (4.90 MB/s) - ‘./models/ColorizeVideo_gen.pth’ saved [874066230/874066230]

# %%
import functools
from fastai.basic_train import Recorder
from torch.nn import Sequential
from torch.nn.modules.conv import Conv2d
from torch.nn.modules.batchnorm import BatchNorm2d
from torch.nn.modules.activation import ReLU
from fastai.callbacks import hooks # Import the module
from fastai.callbacks.hooks import Hook # Import the Hook class
# torch.serialization.add_safe_globals([functools.partial, Recorder, Sequential, Conv2d, BatchNorm2d, ReLU, Hook]) # Removed getattr
colorizer = get_video_colorizer()
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4804/596628725.py in <cell line: 0>()
#       8 from fastai.callbacks.hooks import Hook # Import the Hook class
#       9 # torch.serialization.add_safe_globals([functools.partial, Recorder, Sequential, Conv2d, BatchNorm2d, ReLU, Hook]) # Removed getattr
# ---> 10 colorizer = get_video_colorizer()
#
# /content/DeOldify/deoldify/visualize.py in get_video_colorizer(render_factor)
#     409
#     410 def get_video_colorizer(render_factor: int = 21) -> VideoColorizer:
# --> 411     return get_stable_video_colorizer(render_factor=render_factor)
#     412
#     413
#
# /content/DeOldify/deoldify/visualize.py in get_stable_video_colorizer(root_folder, weights_name, results_dir, render_factor)
#     430     render_factor: int = 21
#     431 ) -> VideoColorizer:
# --> 432     learn = gen_inference_wide(root_folder=root_folder, weights_name=weights_name)
#     433     filtr = MasterFilter([ColorizerFilter(learn=learn)], render_factor=render_factor)
#     434     vis = ModelImageVisualizer(filtr, results_dir=results_dir)
#
# /content/DeOldify/deoldify/generators.py in gen_inference_wide(root_folder, weights_name, nf_factor, arch)
#      17     )
#      18     learn.path = root_folder
# ---> 19     learn.load(weights_name)
#      20     learn.model.eval()
#      21     return learn
#
# /content/DeOldify/fastai/basic_train.py in load(self, file, device, strict, with_opt, purge, remove_module)
#     265              with_opt:bool=None, purge:bool=True, remove_module:bool=False):
#     266         "Load model and optimizer state (if `with_opt`) `file` from `self.model_dir` using `device`. `file` can be file-like (file or buffer)"
# --> 267         if purge: self.purge(clear_opt=ifnone(with_opt, False))
#     268         if device is None: device = self.data.device
#     269         elif isinstance(device, int): device = torch.device('cuda', device)
#
# /content/DeOldify/fastai/basic_train.py in purge(self, clear_opt)
#     320         for a in attrs_del: delattr(self, a)
#     321         gc.collect()
# --> 322         state = torch.load(tmp_file)
#     323         os.remove(tmp_file)
#     324
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1538                 if weights_only:
#    1539                     try:
# -> 1540                         return _load(
#    1541                             opened_zipfile,
#    1542                             map_location,
#
# /usr/local/lib/python3.12/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    2141     global _serialization_tls
#    2142     _serialization_tls.map_location = map_location
# -> 2143     result = unpickler.load()
#    2144     _serialization_tls.map_location = None
#    2145
#
# /usr/local/lib/python3.12/dist-packages/torch/_weights_only_unpickler.py in load(self)
#     336                 if full_path in _get_allowed_globals():
#     337                     self.append(_get_allowed_globals()[full_path])
# --> 338                 elif full_path in _get_user_allowed_globals():
#     339                     self.append(_get_user_allowed_globals()[full_path])
#     340                 elif full_path in (
#
# /usr/local/lib/python3.12/dist-packages/torch/_weights_only_unpickler.py in _get_user_allowed_globals()
#     143             rc[name] = f
#     144         else:
# --> 145             module, name = f.__module__, f.__qualname__
#     146             rc[f"{module}.{name}"] = f
#     147     return rc
#
# AttributeError: 'str' object has no attribute '__module__'

# %% [markdown]
# #◢ Instructions

# %% [markdown]
# ### source_url
# Type in a url hosting a video from YouTube, Imgur, Twitter, Reddit, Vimeo, etc.  Many sources work!  GIFs also work.  Full list here: https://ytdl-org.github.io/youtube-dl/supportedsites.html NOTE: If you want to use your own video, upload it first to a site like YouTube.
#
# ### render_factor
# The default value of 21 has been carefully chosen and should work -ok- for most scenarios (but probably won't be the -best-). This determines resolution at which the color portion of the video is rendered. Lower resolution will render faster, and colors also tend to look more vibrant. Older and lower quality film in particular will generally benefit by lowering the render factor. Higher render factors are often better for higher quality videos and inconsistencies (flashy render) will generally be reduced, but the colors may get slightly washed out.
#
# ### watermarked
# Selected by default, this places a watermark icon of a palette at the bottom left corner of the image.  This is intended to be a standard way to convey to others viewing the image that it is colorized by AI. We want to help promote this as a standard, especially as the technology continues to improve and the distinction between real and fake becomes harder to discern. This palette watermark practice was initiated and lead by the company MyHeritage in the MyHeritage In Color feature (which uses a newer version of DeOldify than what you're using here).
#
# ### How to Download a Copy
# Simply right click on the displayed video and click "Save video as..."!
#
# ## Pro Tips
# 1. If a video takes a long time to render and you're wondering how well the frames will actually be colorized, you can preview how well the frames will be rendered at each render_factor by using the code at the bottom. Just stop the video rendering by hitting the stop button on the cell, then run that bottom cell under "See how well render_factor values perform on a frame here". It's not perfect and you may still need to experiment a bit especially when it comes to figuring out how to reduce frame inconsistency.  But it'll go a long way in narrowing down what actually works.
# 2. If videos are taking way too much time for your liking, running the Jupyter notebook VideoColorizer.ipynb on your own machine (with DeOldify installed) will generally be much faster (as long as you have the hardware for it).
# 3. Longer videos (running multiple minutes) are going to have a rough time on Colabs. You'll be much better off using a local install of DeOldify instead in this case.
#
# ## Troubleshooting
# The video player may wind up not showing up, in which case- make sure to wait for the Jupyter cell to complete processing first (the play button will stop spinning).  Then follow these alternative download instructions
#
# 1. In the menu to the left, click Files
# 2. If you don't see the 'DeOldify' folder, click "Refresh"
# 3. By default, rendered video will be in /DeOldify/video/result/
#
# If a video you downloaded doesn't play, it's probably because the cell didn't complete processing and the video is in a half-finished state.

# %% [markdown]
# #◢ Colorize!!

# %%
source_url = 'https://youtu.be/rZzPmbRUqJo' #@param {type:"string"}
render_factor = 21  #@param {type: "slider", min: 5, max: 40}
watermarked = False #@param {type:"boolean"}

if source_url is not None and source_url !='':
    video_path = colorizer.colorize_from_url(source_url, 'video.mp4', render_factor, watermarked=watermarked)
    show_video_in_notebook(video_path)
else:
    print('Provide a video url and try again.')

# %% [markdown]
# ## See how well render_factor values perform on a frame here

# %%
for i in range(10,40,2):
    colorizer.vis.plot_transformed_image('video/bwframes/video/00001.jpg', render_factor=i, display_render_factor=True, figsize=(8,8))

# %% [markdown]
# ---
# #⚙ Recommended video and gif sources
# * [/r/Nickelodeons/](https://www.reddit.com/r/Nickelodeons/)
# * [r/silentmoviegifs](https://www.reddit.com/r/silentmoviegifs/)
# * https://twitter.com/silentmoviegifs
